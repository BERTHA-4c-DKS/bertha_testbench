# %%
import pandas as pd

db = pd.read_csv("results.csv", sep=",")

for c in db.columns:
    print("\"%s\""%(c))
#print(db)
# Out:
# "System"
# "Scheduling"
# "NumOfThreads"
# "FittedDensityUnique"
# "FittedDensity"
# "FittedDensityAvgStdev"
# "FunctionalEnergyUnique"
# "FunctionalEnergy"
# "FunctionalEnergyAvgStdev"
# "VxcUnique"
# "Vxc"
# "VxcAvgStdev"
# "TotalEnergyUnique"
# "TotalEnergy"
# "TotalEnergyAvgStdev"
# "ConvergenceUnique"
# "ConvergenceSet"
# "CpuTime"
# "WallTime"
# "Memory"

# %%
import numpy as np 

systems = list(set(db["System"].values))
scheds = list(set(db["Scheduling"].values))

#print(scheds)
#print(systems)

for sysin in systems:
    db1 = db[db["System"] == sysin]
    
    sys = sysin.replace(" ", "")

    print(sys)

    fp = open(sys+"_time.csv", "w")
    print("Scheduling , #t , Walltime , Speedup , Memory ")
    print("Scheduling , #t , Walltime , Speedup , Memory ", file=fp)
    
    for schedin in scheds:
        selected = db1[db1["Scheduling"] == schedin]

        sched = schedin.replace(" ", "")

        walltimepert = {}
        memorypert = {}
        for index, row in selected.iterrows():
            nomuft = row["NumOfThreads"]
            walltime = row["WallTime"]
            memory = row["Memory"]
         
            walltimepert[nomuft] = walltime
            memorypert[nomuft] = memory

        serial = 0.0
        for nomuft in walltimepert:
            avg = walltimepert[nomuft]
            speedup = 1.0
            if nomuft == 1:
                 serial = avg
            else:
                speedup = serial/avg
             
            print(" %7s , %3d , %10.3f , %5.2f , %15.3f "%(sched, nomuft, avg, speedup, \
                                                     memorypert[nomuft]))
            print(" %7s , %3d , %10.3f , %5.2f , %15.3f "%(sched, nomuft, avg, speedup, \
                                                     memorypert[nomuft]), file=fp)            
    fp.close()
# Out:
# Au2
# Scheduling , #t , Walltime , Speedup , Memory
#   static ,   1 ,     22.927 ,  1.00 ,      277725.000
#   static ,   2 ,     20.170 ,  1.14 ,      345451.000
#   static ,   3 ,     19.238 ,  1.19 ,      403139.000
#   static ,   4 ,     18.713 ,  1.23 ,      470333.000
#   static ,   5 ,     18.993 ,  1.21 ,      525109.000
#   static ,   6 ,     18.789 ,  1.22 ,      579554.000
#   static ,   7 ,     18.596 ,  1.23 ,      642581.000
#   static ,   8 ,     18.597 ,  1.23 ,      701712.000
#  dynamic ,   1 ,     22.957 ,  1.00 ,      278049.000
#  dynamic ,   2 ,     19.844 ,  1.16 ,      344964.000
#  dynamic ,   3 ,     18.743 ,  1.22 ,      411192.000
#  dynamic ,   4 ,     18.405 ,  1.25 ,      480263.000
#  dynamic ,   5 ,     18.354 ,  1.25 ,      547371.000
#  dynamic ,   6 ,     18.266 ,  1.26 ,      612903.000
#  dynamic ,   7 ,     18.333 ,  1.25 ,      680347.000
#  dynamic ,   8 ,     18.374 ,  1.25 ,      739454.000
# H2O
# Scheduling , #t , Walltime , Speedup , Memory
#   static ,   1 ,      0.613 ,  1.00 ,       70967.000
#   static ,   2 ,      0.528 ,  1.16 ,       92944.000
#   static ,   3 ,      0.488 ,  1.25 ,      115570.000
#   static ,   4 ,      0.470 ,  1.30 ,      134599.000
#   static ,   5 ,      0.512 ,  1.20 ,      160278.000
#   static ,   6 ,      0.507 ,  1.21 ,      184762.000
#   static ,   7 ,      0.525 ,  1.17 ,      201840.000
#   static ,   8 ,      0.537 ,  1.14 ,      228057.000
#  dynamic ,   1 ,      0.613 ,  1.00 ,       70946.000
#  dynamic ,   2 ,      0.444 ,  1.38 ,      109670.000
#  dynamic ,   3 ,      0.394 ,  1.56 ,      146202.000
#  dynamic ,   4 ,      0.378 ,  1.62 ,      196171.000
#  dynamic ,   5 ,      0.394 ,  1.56 ,      229329.000
#  dynamic ,   6 ,      0.423 ,  1.45 ,      272617.000
#  dynamic ,   7 ,      0.446 ,  1.37 ,      311073.000
#  dynamic ,   8 ,      0.450 ,  1.36 ,      349484.000
# PbCl2
# Scheduling , #t , Walltime , Speedup , Memory
#   static ,   1 ,     17.384 ,  1.00 ,      209102.000
#   static ,   2 ,     15.006 ,  1.16 ,      255796.000
#   static ,   3 ,     14.253 ,  1.22 ,      301334.000
#   static ,   4 ,     13.594 ,  1.28 ,      344679.000
#   static ,   5 ,     13.667 ,  1.27 ,      385085.000
#   static ,   6 ,     13.610 ,  1.28 ,      424063.000
#   static ,   7 ,     12.981 ,  1.34 ,      470942.000
#   static ,   8 ,     12.800 ,  1.36 ,      511180.000
#  dynamic ,   1 ,     17.372 ,  1.00 ,      209581.000
#  dynamic ,   2 ,     13.791 ,  1.26 ,      259464.000
#  dynamic ,   3 ,     12.570 ,  1.38 ,      309355.000
#  dynamic ,   4 ,     12.013 ,  1.45 ,      361677.000
#  dynamic ,   5 ,     12.049 ,  1.44 ,      417927.000
#  dynamic ,   6 ,     12.039 ,  1.44 ,      468115.000
#  dynamic ,   7 ,     11.955 ,  1.45 ,      508029.000
#  dynamic ,   8 ,     12.138 ,  1.43 ,      575961.000

# %%
import numpy as np 

systems = list(set(db["System"].values))
scheds = list(set(db["Scheduling"].values))

for sys in systems:
    db1 = db[db["System"] == sys]
    sysout = sys.replace(" ", "")
    fp = open(sysout + "_numeric.csv", "w")
    
    print("Scheduling , #t , TotalEnergy Unique , TotalEnergy AvgStdev , Num. Of Iter", file=fp)
    for sched in scheds:
        selected = db1[db1["Scheduling"] == sched]

        #print(sys, ", Model %1d %7s , "%(model, sched), end="")
        
        for index, row in selected.iterrows():
            val = row[["NumOfThreads", \
                       "TotalEnergyUnique", \
                       "TotalEnergyAvgStdev", \
                       "ConvergenceSet"]].values
            
            checkfalsevaues = row[["FittedDensityUnique", \
                                   "FunctionalEnergyUnique", \
                                   "VxcUnique", \
                                   "TotalEnergyUnique", \
                                   "ConvergenceUnique"]]
            
            if checkfalsevaues.values.tolist().count(" False ") > 0 :
                print(sys, "Scheduling %8s #threads %2d "%(sched, row["NumOfThreads"]))
                exit(1)
            
            print("%7s , "%(sched), end="", file=fp)
            for i, v in enumerate(val):
                if (i == (len(val)-1)):
                    print(v.replace("{", "").replace("}", ""), file=fp)
                elif (i == (len(val)-2)):
                    print(v.replace("+/-", "").replace(" 0.0", ""), " , ", end="", file=fp)
                else:
                    print(v, " , ", end="", file=fp)

    fp.close()
